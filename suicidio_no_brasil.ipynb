# %% [markdown]
# <a href="https://colab.research.google.com/github/barbosa-loha/Estatistica/blob/main/suicidio_no_brasil.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_excel('/content/VIOLBR_21.xlsx')

# %%
df
# Out:
#        SG_UF_NOT DT_NOTIFIC  ID_MUNICIP CS_SEXO CS_RACA CS_ESCOL_N  \
# 0      Sao Paulo 2021-01-01      355030       F  Branca        NaN
# 1      Sao Paulo 2021-01-01      355030       F   Parda        NaN
# 2      Sao Paulo 2021-01-01      355030       F   Preta        NaN
# 3      Sao Paulo 2021-01-01      354870       F   Parda        NaN
# 4      Sao Paulo 2021-01-01      355030       F  Branca        NaN
# ...          ...        ...         ...     ...     ...        ...
# 25635  Tocantins 2021-09-16      170210       F   Parda        NaN
# 25636  Tocantins 2021-09-16      170210       F   Parda        NaN
# 25637     Parana 2021-09-16      412770       M  Branca        NaN
# 25638       Acre 2021-09-16      120020       F  Branca        NaN
# 25639     Parana 2021-09-19      410830       F   Preta        NaN
#
#                   VIOL_ESPEC  NUM_ENVOLV     CICL_VID
# 0                     OUTROS         1.0       Adulta
# ...

# %%
df.shape
# Out:
# (25640, 9)

# %%
df.isnull().sum()
# Out:
# SG_UF_NOT         0
# DT_NOTIFIC        0
# ID_MUNICIP        0
# CS_SEXO           0
# CS_RACA          41
# CS_ESCOL_N    25459
# VIOL_ESPEC        0
# NUM_ENVOLV      217
# CICL_VID        192
# dtype: int64

# %%
import seaborn as sns

# %%
ax=sns.countplot(data = df, y = 'VIOL_ESPEC', order=df['VIOL_ESPEC'].value_counts().index, color = 'dodgerblue')
ax.set_ylabel('Violência especificada')
ax.set_xlabel('Contagem')
ax.set_title('Tipo de violência especificada')
# Out:
# Text(0.5, 1.0, 'Tipo de violência especificada')

# %%
ax=sns.countplot(data = df, y = 'SG_UF_NOT', order=df['SG_UF_NOT'].value_counts().index, color = 'dodgerblue')
ax.set_ylabel('Unidade Federativa')
ax.set_xlabel('Contagem')
ax.set_title('Notificação por Fnidade Federativa')
# Out:
# Text(0.5, 1.0, 'Notificação por Fnidade Federativa')

# %%
df['NUM_ENVOLV'].value_counts()
# Out:
# 1.0    24987
# 9.0      242
# 2.0      194
# Name: NUM_ENVOLV, dtype: int64

# %%
sns.barplot(data=df, y="SG_UF_NOT", hue="CS_SEXO")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-ae1446fadac8> in <cell line: 1>()
# ----> 1 sns.barplot(data=df, y="SG_UF_NOT", hue="CS_SEXO")
#
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, units, seed, orient, color, palette, saturation, width, errcolor, errwidth, capsize, dodge, ci, ax, **kwargs)
#    2753         estimator = "size"
#    2754
# -> 2755     plotter = _BarPlotter(x, y, hue, data, order, hue_order,
#    2756                           estimator, errorbar, n_boot, units, seed,
#    2757                           orient, color, palette, saturation,
#
# ...

# %%
dist_freq_qualitativas_sexo = pd.DataFrame({'Frequência': frequencia, 'Porcentagem(%)': percentual})
dist_freq_qualitativas_sexo
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-64-ea354802b41c> in <cell line: 1>()
# ----> 1 pd.DataFrame[SG_UF_NOT]({'Frequência': frequencia, 'Porcentagem(%)': percentual})
#
# NameError: name 'SG_UF_NOT' is not defined

# %%
df.groupby('SG_UF_NOT')['CS_SEXO']\
    .value_counts()\
    .unstack(level=1)\
    .plot.bar(stacked=True)
# Out:
# <Axes: xlabel='SG_UF_NOT'>

# %%
df.groupby('CS_RACA')['CS_SEXO']\
    .value_counts()\
    .unstack(level=1)\
    .plot.bar(stacked=True)
# Out:
# <Axes: xlabel='CS_RACA'>

# %%
df.groupby('CICL_VID')['CS_SEXO']\
    .value_counts()\
    .unstack(level=1)\
    .plot.bar(stacked=True)
# Out:
# <Axes: xlabel='CICL_VID'>

# %%
df.groupby('VIOL_ESPEC')['CICL_VID']\
    .value_counts()\
    .unstack(level=1)\
    .plot.bar(stacked=True)
# Out:
# <Axes: xlabel='VIOL_ESPEC'>

# %%
df.groupby('CICL_VID')['NUM_ENVOLV']\
    .value_counts()\
    .unstack(level=1)\
    .plot.bar(stacked=True)
# Out:
# <Axes: xlabel='CICL_VID'>
